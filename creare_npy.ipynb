# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from PIL import Image
from matplotlib import pyplot as plt
import numpy as np

im = Image.open('/content/gdrive/MyDrive/REZULTATE/POZE/M_CLUJ_29_08_2020/b234.bmp', 'r')


pix_val = list(im.getdata())
np.save('/content/gdrive/MyDrive/REZULTATE/NPY/M_CLUJ_29_08_2020/b234_M_CJ_2020.npy', pix_val)
#np.savetxt('file.csv', pix_val, fmt='%3.0f', delimiter=',')

# %%
#im = Image.open('/content/gdrive/MyDrive/REZULTATE/POZE/S_CONSTANTA_20_09_2018/b234_cropped.bmp', 'r')

#COD PENTRU A TAIA IMAGINILE CU 1 DIMENSIUNE

v=np.array(im)
lin,col=v.shape
print(lin)
print(col)
#prima e nr de linii 
#a doua e numarul de coloane 
v1=v[:2744,:2744] #patratul de stanga sus 
#print(v1)
v2=v[:2744,2745:5490] #patratul de dreapta sus 
v3=v[2745:5490,:2744] #patratul de stanga jos 
v4=v[2745:5490,2745:5490] #patratul de dreapta jos

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(20,20))
plt.subplot(1,5,1)
plt.imshow(v,cmap="gray")
plt.title("intial")
plt.subplot(1,5,2)
plt.imshow(v1,cmap="gray")
plt.title("stanga sus")
plt.subplot(1,5,3)
plt.imshow(v2,cmap="gray")
plt.title("dreapta sus")
plt.subplot(1,5,4)
plt.imshow(v3,cmap="gray")
plt.title("stanga jos")
plt.subplot(1,5,5)
plt.imshow(v4,cmap="gray")
plt.title("dreapta jos")

#pentru masti
np.save('/content/gdrive/MyDrive/REZULTATE/NPY/M_CLUJ_29_08_2020/NDBI_M_CJ_2020_parte1.npy', v1.flatten())
np.save('/content/gdrive/MyDrive/REZULTATE/NPY/M_CLUJ_29_08_2020/NDBI_M_CJ_2020_parte2.npy', v2.flatten())
np.save('/content/gdrive/MyDrive/REZULTATE/NPY/M_CLUJ_29_08_2020/NDBI_M_CJ_2020_parte3.npy', v3.flatten())
np.save('/content/gdrive/MyDrive/REZULTATE/NPY/M_CLUJ_29_08_2020/NDBI_M_CJ_2020_parte4.npy', v4.flatten())
# Out:
# 5490
# 5490

# %%
#COD PENTRU A TAIA IMAGINILE CU 3 DIMENSIUNI
v=np.array(im)
lin,col,C=v.shape
print(lin)
print(col)
#prima e nr de linii 
#a doua e numarul de coloane 
v1=v[:2744,:2744] #patratul de stanga sus 
#print(v1)
v2=v[:2744,2745:5490] #patratul de dreapta sus 
v3=v[2745:5490,:2744] #patratul de stanga jos 
v4=v[2745:5490,2745:5490] #patratul de dreapta jos


import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(20,20))
plt.subplot(1,5,1)
plt.imshow(v,cmap="gray")
plt.title("intial")
plt.subplot(1,5,2)
plt.imshow(v1,cmap="gray")
plt.title("stanga sus")
plt.subplot(1,5,3)
plt.imshow(v2,cmap="gray")
plt.title("dreapta sus")
plt.subplot(1,5,4)
plt.imshow(v3,cmap="gray")
plt.title("stanga jos")
plt.subplot(1,5,5)
plt.imshow(v4,cmap="gray")
plt.title("dreapta jos")

L1,C1,Channel1=v1.shape
new_arr1 = v1.reshape(L1*C1,Channel1)
L2,C2,Channel2=v2.shape
new_arr2 = v2.reshape(L2*C2,Channel2)
L3,C3,Channel3=v3.shape
new_arr3 = v3.reshape(L3*C3,Channel3)
L4,C4,Channel4=v4.shape
new_arr4 = v4.reshape(L4*C4,Channel4)

#pentru imagini 3D
np.save('/content/gdrive/MyDrive/REZULTATE/NPY/M_CLUJ_29_08_2020/b234_M_CJ_2020_parte1.npy',new_arr1)
np.save('/content/gdrive/MyDrive/REZULTATE/NPY/M_CLUJ_29_08_2020/b234_M_CJ_2020_parte2.npy',new_arr2)
np.save('/content/gdrive/MyDrive/REZULTATE/NPY/M_CLUJ_29_08_2020/b234_M_CJ_2020_parte3.npy',new_arr3)
np.save('/content/gdrive/MyDrive/REZULTATE/NPY/M_CLUJ_29_08_2020/b234_M_CJ_2020_parte4.npy',new_arr4)
# Out:
# 5490
# 5490

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
image=Image.open(r'/content/drive/MyDrive/REZULTATE/POZE/S_CONSTANTA_20_09_2018/b41112_cropped.bmp')
v=np.array(image)
print(v.shape)

v4=v[444:886,236:473] #patratul de dreapta jos
#print(v4)

print(v4.shape)
lin,col,c=v4.shape
new_arr = v4.reshape(lin*col,c)
print(new_arr.shape)
# (5000, 25)

#plt.imshow(v4)
np.save('/content/drive/MyDrive/x.npy', new_arr)
# Out:
# (886, 473, 3)
# (442, 237, 3)
# (104754, 3)

# %%
import numpy as np

data = np.load('/content/gdrive/MyDrive/npy-uri/constanta 2019_vechi/mask_constanta_2019_vechi.npy')
print(type(data))
data.shape
#data.reshape(())
#for i in range(234567,234579):
  #for j in range(3):
    #print(np.concatenate((data[9999],data[200]),axis=0))
# Out:
# <class 'numpy.ndarray'>
# (473360,)
